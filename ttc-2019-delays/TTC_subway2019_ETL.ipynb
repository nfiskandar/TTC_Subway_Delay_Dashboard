# %%
# Dependencies
import pandas as pd

# %%
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

# %%
engine_heroku = create_engine('postgres://omtjgoefxknxjr:4dc783a299806ee57d98e35b67ccfbfc26f71b0f7ef0806de7a83021d71b69a8@ec2-184-72-236-57.compute-1.amazonaws.com:5432/d397mvjlukaah3')

# %%
# Store filepath in a variable
file_one = "Data/ttc-subway-delay-2019-masterv3.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
subway_data_df = pd.read_csv(file_one, encoding="ISO-8859-1")
subway_data_df.head()
# Out:
#          date  time      day                station   code  min_delay  \
# 0  2019-01-01  3:03  Tuesday         DUPONT STATION  MUATC         11
# 1  2019-01-01  3:08  Tuesday  EGLINTON WEST STATION  EUATC         11
# 2  2019-01-01  3:09  Tuesday         DUPONT STATION  EUATC          6
# 3  2019-01-01  3:26  Tuesday  ST CLAIR WEST STATION  EUATC          4
# 4  2019-01-01  8:04  Tuesday     DAVISVILLE STATION  MUNOA          5
#
#    min_gap bound line  vehicle  \
# 0       16     N   YU     6061
# 1       16     S   YU     5656
# 2       11     N   YU     5381
# 3        9     N   YU     5571
# 4       10     S   YU        0
#
#                                            code_info latitude  longitude  \
# 0                                        ATC Project  43.4029   -79.2425
# 1                                 ATC RC&S Equipment  43.4157   -79.2609
# 2                                 ATC RC&S Equipment  43.4029   -79.2425
# ...

# %%
len(subway_data_df)
# Out:
# 6677

# %%
subway_data_df['id'] = subway_data_df.index +1

# %%
subway_data_df.head()
# Out:
#          date  time      day                station   code  min_delay  \
# 0  2019-01-01  3:03  Tuesday         DUPONT STATION  MUATC         11
# 1  2019-01-01  3:08  Tuesday  EGLINTON WEST STATION  EUATC         11
# 2  2019-01-01  3:09  Tuesday         DUPONT STATION  EUATC          6
# 3  2019-01-01  3:26  Tuesday  ST CLAIR WEST STATION  EUATC          4
# 4  2019-01-01  8:04  Tuesday     DAVISVILLE STATION  MUNOA          5
#
#    min_gap bound line  vehicle  \
# 0       16     N   YU     6061
# 1       16     S   YU     5656
# 2       11     N   YU     5381
# 3        9     N   YU     5571
# 4       10     S   YU        0
#
#                                            code_info latitude  longitude  \
# 0                                        ATC Project  43.4029   -79.2425
# 1                                 ATC RC&S Equipment  43.4157   -79.2609
# 2                                 ATC RC&S Equipment  43.4029   -79.2425
# ...

# %%
subway_data_df.to_sql('ttc_subway_2019', con=engine_heroku, if_exists='replace', index=False)

# %%
engine_heroku.execute('ALTER TABLE ttc_subway_2019 ADD PRIMARY KEY (id);')

# %%
#Check if table is loaded
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine_heroku, reflect=True)

# %%
# Save references to each table
subway_tb_heroku = Base.classes.ttc_subway_2019

# %%
test_df=pd.read_sql('SELECT * FROM ttc_subway_2019;', engine_heroku)

# %%
test_df
# Out:
#             date         time      day                station   code  \
# 0     2019-01-01         3:03  Tuesday         DUPONT STATION  MUATC
# 1     2019-01-01         3:08  Tuesday  EGLINTON WEST STATION  EUATC
# 2     2019-01-01         3:09  Tuesday         DUPONT STATION  EUATC
# 3     2019-01-01         3:26  Tuesday  ST CLAIR WEST STATION  EUATC
# 4     2019-01-01         8:04  Tuesday     DAVISVILLE STATION  MUNOA
# ...          ...          ...      ...                    ...    ...
# 6672       43830  0.656944444  Tuesday   CASTLE FRANK STATION   SUDP
# 6673       43830  0.686805556  Tuesday        CHESTER STATION   MUIR
# 6674       43830  0.711111111  Tuesday      LANSDOWNE STATION   SUDP
# 6675       43830  0.869444444  Tuesday         WILSON STATION   MUTO
# 6676       43830  0.879861111  Tuesday  EGLINTON WEST STATION   SUDP
#
#       min_delay  min_gap bound line  vehicle  \
# 0            11       16     N   YU     6061
# ...

# %%
# Store filepath in a variable
file_two = "Data/TTC Stations In order by line v4.xlsx"

# %%
stations_delay_df = pd.read_excel(file_two, encoding="ISO-8859-1")
stations_delay_df.head()
# Out:
#                   station   latitude    longitude                 line_name  \
# 0      VAUGHAN MC STATION  43.794167     -79.5275  Yonge University Spadina
# 1     HIGHWAY 407 STATION  43.783889     -79.5231  Yonge University Spadina
# 2  PIONEER VILLAGE STATIO  43.776944     -79.5094  Yonge University Spadina
# 3  YORK UNIVERSITY STATIO  43.774167   -79.499722  Yonge University Spadina
# 4      FINCH WEST STATION  43.765278     -79.4911  Yonge University Spadina
#
#    avg_delay_time  num_delays
# 0            4.92          241
# 1            6.13           24
# 2           14.05           20
# 3            5.29           21
# 4            6.58           31

# %%
len(stations_delay_df)
# Out:
# 80

# %%
stations_delay_df['id'] =stations_delay_df.index+1

# %%
stations_delay_df.head()
# Out:
#                   station   latitude    longitude                 line_name  \
# 0      VAUGHAN MC STATION  43.794167     -79.5275  Yonge University Spadina
# 1     HIGHWAY 407 STATION  43.783889     -79.5231  Yonge University Spadina
# 2  PIONEER VILLAGE STATIO  43.776944     -79.5094  Yonge University Spadina
# 3  YORK UNIVERSITY STATIO  43.774167   -79.499722  Yonge University Spadina
# 4      FINCH WEST STATION  43.765278     -79.4911  Yonge University Spadina
#
#    avg_delay_time  num_delays   id
# 0            4.92          241   1
# 1            6.13           24   2
# 2           14.05           20   3
# 3            5.29           21   4
# 4            6.58           31   5

# %%
stations_delay_df.to_sql('station_in_line', con=engine_heroku, if_exists='replace', index=False)

# %%
engine_heroku.execute('ALTER TABLE station_in_line ADD PRIMARY KEY (id);')

# %%
#Check if table is loaded
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine_heroku, reflect=True)

# %%
# Save references to each table
subway_tb_heroku = Base.classes.station_in_line

# %%
test_delay_df=pd.read_sql('SELECT * FROM station_in_line;', engine_heroku)
test_delay_df.head()
# Out:
#                   station   latitude    longitude                 line_name  \
# 0      VAUGHAN MC STATION  43.794167     -79.5275  Yonge University Spadina
# 1     HIGHWAY 407 STATION  43.783889   -79.523056  Yonge University Spadina
# 2  PIONEER VILLAGE STATIO  43.776944   -79.509444  Yonge University Spadina
# 3  YORK UNIVERSITY STATIO  43.774167   -79.499722  Yonge University Spadina
# 4      FINCH WEST STATION  43.765278   -79.491111  Yonge University Spadina
#
#    avg_delay_time  num_delays   id
# 0            4.92          241   1
# 1            6.13           24   2
# 2           14.05           20   3
# 3            5.29           21   4
# 4            6.58           31   5
